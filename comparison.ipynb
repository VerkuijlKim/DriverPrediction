# %%
# Own files
from Functions2 import *
from DataDefined2 import *
from ood_models import OCSVM, LocalOutlierFactorModel, IsolationForestModel

from itertools import permutations
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.metrics import roc_curve, roc_auc_score

# %%
# Load and prepare dataset
df = pd.read_csv('Driving Data(KIA SOUL)_(150728-160714)_(10 Drivers_A-J).csv')
columns_to_drop = one_val_col + irrelevant_col
df = df.drop(columns_to_drop, axis=1)
df = addRideNumbers(df)
df = add_delta(df, delta_col)
encoder = LabelEncoder()
df['Class'] = encoder.fit_transform(df['Class'])

# %%
number_of_classes = list(range(10))
# All possible ordered pairs of class comparisons, where one is ID and the other OOD
class_comparisons = list(permutations(number_of_classes, 2))

# %%
models = {
    'IsolationForest': IsolationForestModel(),
    'OneClassSVM': OCSVM(),
    'LOF': LocalOutlierFactorModel()
}

results = []

for CLASS_ID, CLASS_OOD in class_comparisons:
    print(f"Evaluating ID: {CLASS_ID} vs OOD: {CLASS_OOD}")
    
    # Extract ID and OOD data
    id_data = df[df['Class'] == CLASS_ID]
    ood_data = df[df['Class'] == CLASS_OOD]

    # Apply feature selection and sliding window
    id_windows = create_sliding_windows(id_data, window_size=60, overlap=20)
    ood_windows = create_sliding_windows(ood_data, window_size=60, overlap=20)

    n_id_samples = len(id_windows)
    train_idx = int(n_id_samples * 0.7)
    val_idx = train_idx + int(n_id_samples * 0.1)

    train_data = id_windows[:train_idx]
    val_data = id_windows[train_idx:val_idx]
    test_id_data = id_windows[val_idx:]
    train_data += val_data

    train_data = np.array([extract_features_from_window(window) for window in train_data])
    test_id_data = np.array([extract_features_from_window(window) for window in test_id_data])
    test_ood_data = np.array([extract_features_from_window(window) for window in ood_windows])

    for model_name, model in models.items():
        print(f"Evaluating with {model_name}...")

        if model_name == 'LOF': 
            local_outlier_factor = LocalOutlierFactorModel()
            local_outlier_factor.train_model(train_data)
            ood_scores, ood_labels = local_outlier_factor.test_model(test_id_data, test_ood_data)    

        elif model_name == 'OneClassSVM':
            one_class_svm = OCSVM()
            one_class_svm.train_model(train_data)
            ood_scores, ood_labels = one_class_svm.test_model(test_id_data, test_ood_data)

        elif model_name == 'IsolationForest':
            isolation_forest = IsolationForestModel()
            isolation_forest.train_model(train_data)
            ood_scores, ood_labels = isolation_forest.test_model(test_id_data, test_ood_data)    
            
        auroc, fpr95 = evaluate_ood_performance(ood_scores, ood_labels)

        results.append({
            'CLASS_ID': CLASS_ID,
            'CLASS_OOD': CLASS_OOD,
            'Model': model_name,
            'AUROC': auroc,
            'FPR95': fpr95
        })

results_df = pd.DataFrame(results)
results_df.to_csv('comparison.csv')
# Out:
# Evaluating ID: 0 vs OOD: 1
# 180
# 125
# 143
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 0 vs OOD: 2
# 180
# 125
# 143
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 0 vs OOD: 3
# 180
# 125
# 143
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 0 vs OOD: 4
# 180
# 125
# 143
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 0 vs OOD: 5
# 180
# 125
# 143
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 0 vs OOD: 6
# 180
# 125
# 143
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 0 vs OOD: 7
# 180
# 125
# 143
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 0 vs OOD: 8
# 180
# 125
# 143
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 0 vs OOD: 9
# 180
# 125
# 143
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 1 vs OOD: 0
# 321
# 224
# 256
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 1 vs OOD: 2
# 321
# 224
# 256
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 1 vs OOD: 3
# 321
# 224
# 256
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 1 vs OOD: 4
# 321
# 224
# 256
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 1 vs OOD: 5
# 321
# 224
# 256
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 1 vs OOD: 6
# 321
# 224
# 256
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 1 vs OOD: 7
# 321
# 224
# 256
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 1 vs OOD: 8
# 321
# 224
# 256
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 1 vs OOD: 9
# 321
# 224
# 256
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 2 vs OOD: 0
# 187
# 130
# 148
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 2 vs OOD: 1
# 187
# 130
# 148
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 2 vs OOD: 3
# 187
# 130
# 148
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 2 vs OOD: 4
# 187
# 130
# 148
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 2 vs OOD: 5
# 187
# 130
# 148
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 2 vs OOD: 6
# 187
# 130
# 148
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 2 vs OOD: 7
# 187
# 130
# 148
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 2 vs OOD: 8
# 187
# 130
# 148
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 2 vs OOD: 9
# 187
# 130
# 148
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 3 vs OOD: 0
# 330
# 230
# 263
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 3 vs OOD: 1
# 330
# 230
# 263
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 3 vs OOD: 2
# 330
# 230
# 263
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 3 vs OOD: 4
# 330
# 230
# 263
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 3 vs OOD: 5
# 330
# 230
# 263
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 3 vs OOD: 6
# 330
# 230
# 263
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 3 vs OOD: 7
# 330
# 230
# 263
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 3 vs OOD: 8
# 330
# 230
# 263
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 3 vs OOD: 9
# 330
# 230
# 263
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 4 vs OOD: 0
# 210
# 147
# 168
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 4 vs OOD: 1
# 210
# 147
# 168
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 4 vs OOD: 2
# 210
# 147
# 168
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 4 vs OOD: 3
# 210
# 147
# 168
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 4 vs OOD: 5
# 210
# 147
# 168
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 4 vs OOD: 6
# 210
# 147
# 168
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 4 vs OOD: 7
# 210
# 147
# 168
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 4 vs OOD: 8
# 210
# 147
# 168
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 4 vs OOD: 9
# 210
# 147
# 168
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 5 vs OOD: 0
# 274
# 191
# 218
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 5 vs OOD: 1
# 274
# 191
# 218
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 5 vs OOD: 2
# 274
# 191
# 218
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 5 vs OOD: 3
# 274
# 191
# 218
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 5 vs OOD: 4
# 274
# 191
# 218
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 5 vs OOD: 6
# 274
# 191
# 218
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 5 vs OOD: 7
# 274
# 191
# 218
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 5 vs OOD: 8
# 274
# 191
# 218
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 5 vs OOD: 9
# 274
# 191
# 218
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 6 vs OOD: 0
# 186
# 130
# 148
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 6 vs OOD: 1
# 186
# 130
# 148
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 6 vs OOD: 2
# 186
# 130
# 148
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 6 vs OOD: 3
# 186
# 130
# 148
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 6 vs OOD: 4
# 186
# 130
# 148
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 6 vs OOD: 5
# 186
# 130
# 148
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 6 vs OOD: 7
# 186
# 130
# 148
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 6 vs OOD: 8
# 186
# 130
# 148
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 6 vs OOD: 9
# 186
# 130
# 148
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 7 vs OOD: 0
# 246
# 172
# 196
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 7 vs OOD: 1
# 246
# 172
# 196
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 7 vs OOD: 2
# 246
# 172
# 196
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 7 vs OOD: 3
# 246
# 172
# 196
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 7 vs OOD: 4
# 246
# 172
# 196
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 7 vs OOD: 5
# 246
# 172
# 196
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 7 vs OOD: 6
# 246
# 172
# 196
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 7 vs OOD: 8
# 246
# 172
# 196
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 7 vs OOD: 9
# 246
# 172
# 196
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 8 vs OOD: 0
# 194
# 135
# 154
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 8 vs OOD: 1
# 194
# 135
# 154
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 8 vs OOD: 2
# 194
# 135
# 154
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 8 vs OOD: 3
# 194
# 135
# 154
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 8 vs OOD: 4
# 194
# 135
# 154
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 8 vs OOD: 5
# 194
# 135
# 154
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 8 vs OOD: 6
# 194
# 135
# 154
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 8 vs OOD: 7
# 194
# 135
# 154
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 8 vs OOD: 9
# 194
# 135
# 154
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 9 vs OOD: 0
# 222
# 155
# 177
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 9 vs OOD: 1
# 222
# 155
# 177
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 9 vs OOD: 2
# 222
# 155
# 177
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 9 vs OOD: 3
# 222
# 155
# 177
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 9 vs OOD: 4
# 222
# 155
# 177
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 9 vs OOD: 5
# 222
# 155
# 177
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 9 vs OOD: 6
# 222
# 155
# 177
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 9 vs OOD: 7
# 222
# 155
# 177
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...
# Evaluating ID: 9 vs OOD: 8
# 222
# 155
# 177
# Evaluating with IsolationForest...
# Evaluating with OneClassSVM...
# Evaluating with LOF...

# %%
comparison = pd.read_csv('comparison.csv')
comparison
# Out:
#      Unnamed: 0  CLASS_ID  CLASS_OOD            Model     AUROC     FPR95
# 0             0         0          1  IsolationForest  0.654458  0.702703
# 1             1         0          1      OneClassSVM  0.859055  0.405405
# 2             2         0          1              LOF  0.582386  0.783784
# 3             3         0          2  IsolationForest  0.609192  0.729730
# 4             4         0          2      OneClassSVM  0.782772  0.702703
# ..          ...       ...        ...              ...       ...       ...
# 265         265         9          7      OneClassSVM  0.628049  0.911111
# 266         266         9          7              LOF  0.615808  0.822222
# 267         267         9          8  IsolationForest  0.359908  0.933333
# 268         268         9          8      OneClassSVM  0.638660  0.955556
# 269         269         9          8              LOF  0.649255  0.844444
#
# [270 rows x 6 columns]

# %%
iforest_stats = comparison[comparison['Model'] == 'IsolationForest']
print('Isolation forest AUROC mean:', iforest_stats['AUROC'].mean())
print('Isolation forest AUROC min:', iforest_stats['AUROC'].min())
print('Isolation forest AUROC max:', iforest_stats['AUROC'].max(), '\n')

svm_stats = comparison[comparison['Model'] == 'OneClassSVM']
print('OneClassSVM AUROC mean:', svm_stats['AUROC'].mean())
print('OneClassSVM AUROC min:', svm_stats['AUROC'].min())
print('OneClassSVM AUROC max:', svm_stats['AUROC'].max(), '\n')

lof_stats = comparison[comparison['Model'] == 'LOF']
print('LocalOutlierFactor AUROC mean:', lof_stats['AUROC'].mean())
print('LocalOutlierFactor AUROC min:', lof_stats['AUROC'].min())
print('LocalOutlierFactor AUROC max:', lof_stats['AUROC'].max())
# Out:
# Isolation forest AUROC mean: 0.5193385648658873
# Isolation forest AUROC min: 0.2288978494623656
# Isolation forest AUROC max: 0.880101322825781
#
# OneClassSVM AUROC mean: 0.7248994129413119
# OneClassSVM AUROC min: 0.415749578888265
# OneClassSVM AUROC max: 0.9339285714285714
#
# LocalOutlierFactor AUROC mean: 0.4344619709146791
# LocalOutlierFactor AUROC min: 0.0261313868613138
# LocalOutlierFactor AUROC max: 0.9445773524720892

# %%
results_df['AUROC'].mean()
# Out:
# np.float64(0.48205434910566436)

# %%
results_df
# Out:
#     CLASS_ID  CLASS_OOD     AUROC     FPR95
# 0          0          1  0.510819  0.864865
# 1          0          2  0.463362  0.864865
# 2          0          3  0.560033  0.756757
# 3          0          4  0.547362  0.891892
# 4          0          5  0.531466  0.783784
# ..       ...        ...       ...       ...
# 85         9          4  0.458730  0.888889
# 86         9          5  0.413950  0.888889
# 87         9          6  0.343489  0.888889
# 88         9          7  0.391509  0.888889
# 89         9          8  0.373310  0.888889
#
# [90 rows x 4 columns]

# %%
isolation_forest = IsolationForestModel()
isolation_forest.train_model(train_data)
ood_scores, ood_labels = isolation_forest.test_model(test_id_data, test_ood_data)    
evaluate_ood_performance(ood_scores, ood_labels)
# Out:
# AUROC: 0.5743
# FPR95: 0.8955

# %%
local_outlier_factor = LocalOutlierFactorModel()
local_outlier_factor.train_model(train_data)
ood_scores, ood_labels = local_outlier_factor.test_model(test_id_data, test_ood_data)    
evaluate_ood_performance(ood_scores, ood_labels)
# Out:
# AUROC: 0.6457
# FPR95: 0.8657

# %%
one_class_svm = OCSVM()
one_class_svm.train_model(train_data)
ood_scores, ood_labels = one_class_svm.test_model(test_id_data, test_ood_data)    
evaluate_ood_performance(ood_scores, ood_labels)
# Out:
# AUROC: 0.7505
# FPR95: 0.8209
